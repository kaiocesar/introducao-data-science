# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('files/tmdb_5000_movies.csv')
total_language = movies.original_language.value_counts().to_frame().reset_index()
total_language.columns = ['original_language', 'total']

# %% [markdown]
# # The country with the most movies number

# %%
total_others = total_language[total_language.original_language != 'en']
total_biggest = total_language.loc[0].total
total_left = total_language.total.sum() - total_biggest
df_movies_biggest = pd.DataFrame({'language': 
             [total_language.loc[0].original_language, 'others'], 
             'total': 
             [total_biggest, total_left]})

# %% [markdown]
# # Visualization

# %%
sns.barplot(x="language", y="total", data=df_movies_biggest).set_ylabel('Number of movies')
# Out:
# Text(0, 0.5, 'Number of movies')

# %%
sns.barplot(x="original_language", y="total", data=total_others).set_ylabel('number of movies')
# Out:
# Text(0, 0.5, 'number of movies')

# %%
plt.pie(total_others.total,
       labels=total_others.original_language)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe187a3f7f0>,
#   <matplotlib.patches.Wedge at 0x7fe187a3fd30>,
#   <matplotlib.patches.Wedge at 0x7fe187a73240>,
#   <matplotlib.patches.Wedge at 0x7fe187a73710>,
#   <matplotlib.patches.Wedge at 0x7fe187a73be0>,
#   <matplotlib.patches.Wedge at 0x7fe187a330f0>,
#   <matplotlib.patches.Wedge at 0x7fe187a335c0>,
#   <matplotlib.patches.Wedge at 0x7fe187a33a90>,
#   <matplotlib.patches.Wedge at 0x7fe187a33f60>,
#   <matplotlib.patches.Wedge at 0x7fe187a2a470>,
#   <matplotlib.patches.Wedge at 0x7fe18793f438>,
#   <matplotlib.patches.Wedge at 0x7fe187a2add8>,
#   <matplotlib.patches.Wedge at 0x7fe187a3a2e8>,
#   <matplotlib.patches.Wedge at 0x7fe187a3a7b8>,
#   <matplotlib.patches.Wedge at 0x7fe187a3ac88>,
#   <matplotlib.patches.Wedge at 0x7fe187a1e198>,
#   <matplotlib.patches.Wedge at 0x7fe187a1e668>,
#   <matplotlib.patches.Wedge at 0x7fe187a1eb38>,
#   <matplotlib.patches.Wedge at 0x7fe187998048>,
#   <matplotlib.patches.Wedge at 0x7fe187998518>,
#   <matplotlib.patches.Wedge at 0x7fe1879989e8>,
#   <matplotlib.patches.Wedge at 0x7fe187998eb8>,
#   <matplotlib.patches.Wedge at 0x7fe1879b23c8>,
#   <matplotlib.patches.Wedge at 0x7fe1879b2898>,
#   <matplotlib.patches.Wedge at 0x7fe1879b2d68>,
#   <matplotlib.patches.Wedge at 0x7fe187983278>,
#   <matplotlib.patches.Wedge at 0x7fe187983748>,
#   <matplotlib.patches.Wedge at 0x7fe187983c18>,
#   <matplotlib.patches.Wedge at 0x7fe1879a1128>,
#   <matplotlib.patches.Wedge at 0x7fe1879a15f8>,
#   <matplotlib.patches.Wedge at 0x7fe1879a1ac8>,
#   <matplotlib.patches.Wedge at 0x7fe1879a1f98>,
#   <matplotlib.patches.Wedge at 0x7fe1879844a8>,
#   <matplotlib.patches.Wedge at 0x7fe187984978>,
#   <matplotlib.patches.Wedge at 0x7fe187984e48>,
#   <matplotlib.patches.Wedge at 0x7fe186e41358>],
#  [Text(0.8138283050794426, 0.7400564099117863, 'fr'),
#   Text(-0.2641132505042856, 1.0678221719500212, 'es'),
#   Text(-0.836823012386154, 0.713951851276375, 'de'),
#   Text(-1.0896857743981379, 0.15028277703825832, 'zh'),
#   Text(-1.034101857095928, -0.37501113203577463, 'hi'),
#   Text(-0.8292499703604321, -0.7227340359061712, 'ja'),
#   Text(-0.5633356664446874, -0.9448031154221075, 'it'),
#   Text(-0.28656737447526964, -1.0620165440737497, 'cn'),
#   Text(-0.02319123152504682, -1.0997555031825719, 'ko'),
#   Text(0.23021505041200274, -1.0756398238089733, 'ru'),
#   Text(0.45023358146015025, -1.0036382426579642, 'pt'),
#   Text(0.6123319932562713, -0.9138104453522086, 'da'),
#   Text(0.7227340213486737, -0.8292499830480403, 'sv'),
#   Text(0.7980448390854343, -0.7570498232012893, 'fa'),
#   Text(0.8589807592397671, -0.6871332150725019, 'nl'),
#   Text(0.907304426638459, -0.621931408920837, 'he'),
#   Text(0.9448031005880563, -0.5633356913237393, 'th'),
#   Text(0.9731712456944136, -0.512774537739135, 'ar'),
#   Text(0.9939229106868105, -0.4712931652505251, 'ta'),
#   Text(1.0129074169987855, -0.4289738507052015, 'cs'),
#   Text(1.0300910108706036, -0.3858918363007673, 'ro'),
#   Text(1.045443140499157, -0.3421237202873546, 'id'),
#   Text(1.055738795514567, -0.3088941495811333, 'tr'),
#   Text(1.0620165369469312, -0.2865674008872044, 'hu'),
#   Text(1.0678221692453889, -0.26411326143924013, 'vi'),
#   Text(1.0731531115725035, -0.24154171300678973, 'el'),
#   Text(1.0780069941096544, -0.2188627895524222, 'nb'),
#   Text(1.0823816591105155, -0.19608657277123315, 'xx'),
#   Text(1.086275161860261, -0.17322318760911862, 'is'),
#   Text(1.0896857715400696, -0.15028279776183143, 'no'),
#   Text(1.092611971996542, -0.12727560115681205, 'af'),
#   Text(1.095052462415694, -0.10421182541979213, 'ky'),
#   Text(1.0970061579012191, -0.08110172332821074, 'te'),
#   Text(1.0984721899567698, -0.05795556825343485, 'pl'),
#   Text(1.0994499068720383, -0.03478364959383484, 'ps'),
#   Text(1.0999388740124685, -0.011596268200735378, 'sl')])
