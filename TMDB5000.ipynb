# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('files/tmdb_5000_movies.csv')
total_language = movies.original_language.value_counts().to_frame().reset_index()
total_language.columns = ['original_language', 'total']

# %% [markdown]
# # The country with the most movies number

# %%
total_others = total_language[total_language.original_language != 'en']
total_biggest = total_language.loc[0].total
total_left = total_language.total.sum() - total_biggest
df_movies_biggest = pd.DataFrame({'language': 
             [total_language.loc[0].original_language, 'others'], 
             'total': 
             [total_biggest, total_left]})

# %% [markdown]
# # Visualization

# %%
sns.barplot(x="language", y="total", data=df_movies_biggest).set_ylabel('Number of movies')
# Out:
# Text(0, 0.5, 'Number of movies')

# %%
sns.catplot(x="original_language",
            y="total", data=total_others, 
            kind="bar", aspect=2, 
            order=total_others.original_language,
            height=6,
            palette="GnBu_d")

# %%
import matplotlib as plt
import numpy as np

# %% [markdown]
# # The best movies of 2016

# %%
movies_2016 = movies[(movies["release_date"] >= "2016-01-01") & (movies["release_date"] <= "2016-12-31")]
movies_2016
# Out:
#          budget                                             genres  \
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 56    185000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 62    180000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 64    178000000           [{"id": 878, "name": "Science Fiction"}]
# 72    175000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 78    175000000  [{"id": 10751, "name": "Family"}, {"id": 12, "...
# 91    165000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 97     15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 105   170000000                    [{"id": 14, "name": "Fantasy"}]
# 107   160000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 148   144000000  [{"id": 28, "name": "Action"}, {"id": 14, "nam...
# 152   145000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...
